# %% [markdown]
# <a href="https://colab.research.google.com/github/RitulBorse2001/DSBDAL/blob/main/Student_A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/sample_data/Academic-Performance-Dataset.csv")
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp          72       62.0       98.0
# 1        2    Reyansh      M     IT          58       62.0       83.0
# 2        3      Aarav      M     IT          57      -20.0      100.0
# 3        4     Atharv      M     IT          60       89.0       83.0
# 4        5     Vivaan      M   Comp          85       90.0        NaN
# 5        6      Advik      M   ENTC          94       99.0       84.0
# 6        7       Ansh      M   ENTC          98       88.0       95.0
# 7        8     Ishaan      M   ENTC          75       66.0       51.0
# 8        9      Dhruv      M   ENTC          63        NaN        NaN
# 9       10  Siddharth      M   ENTC          96       67.0       78.0
# 10      11     Vihaan      M   ENTC          82       54.0       70.0
# 11      12        NaN      M     IT          75       64.0       67.0
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['Gender']= le.fit_transform(df['Gender'])
df['Gender'].unique()
df
# Out:
#     Rollno       Name  Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed       1   Comp          72       62.0       98.0
# 1        2    Reyansh       1     IT          58       62.0       83.0
# 2        3      Aarav       1     IT          57      -20.0      100.0
# 3        4     Atharv       1     IT          60       89.0       83.0
# 4        5     Vivaan       1   Comp          85       90.0        NaN
# 5        6      Advik       1   ENTC          94       99.0       84.0
# 6        7       Ansh       1   ENTC          98       88.0       95.0
# 7        8     Ishaan       1   ENTC          75       66.0       51.0
# 8        9      Dhruv       1   ENTC          63        NaN        NaN
# 9       10  Siddharth       1   ENTC          96       67.0       78.0
# 10      11     Vihaan       1   ENTC          82       54.0       70.0
# 11      12        NaN       1     IT          75       64.0       67.0
# ...

# %%
import matplotlib.pyplot as plt

df=pd.read_csv("/content/sample_data/Academic-Performance-Dataset.csv")
df
col=['Phy_marks','Che_marks','EM1_marks','PPS_marks','SME_marks']
df.boxplot(col)
# Out:
# <Axes: >

# %%
fig,ax = plt.subplots(figsize=(18,10))
ax.scatter(df['Total Marks'],df['Total Marks'])
plt.show()

# %%
import numpy as np
from scipy import stats
z = np.abs(stats.zscore(df['Phy_marks']))
print(z)
threshold=0.18
sample_outliers = np.where(z < threshold)
sample_outliers
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# Name: Phy_marks, dtype: float64
# (array([], dtype=int64),)

# %%
df.isnull()
# Out:
#     Rollno   Name  Gender  Branch  Attendence  Phy_marks  Che_marks  \
# 0    False  False   False   False       False      False      False
# 1    False  False   False   False       False      False      False
# 2    False  False   False   False       False      False      False
# 3    False  False   False   False       False      False      False
# 4    False  False   False   False       False      False       True
# 5    False  False   False   False       False      False      False
# 6    False  False   False   False       False      False      False
# 7    False  False   False   False       False      False      False
# 8    False  False   False   False       False       True       True
# 9    False  False   False   False       False      False      False
# 10   False  False   False   False       False      False      False
# 11   False   True   False   False       False      False      False
# 12   False  False   False   False       False      False      False
# ...

# %%
series = pd.isnull(df["Phy_marks"])
df[series]
# Out:
#    Rollno   Name Gender Branch  Attendence  Phy_marks  Che_marks  EM1_marks  \
# 8       9  Dhruv      M   ENTC          63        NaN        NaN       97.0
#
#    PPS_marks  SME_marks  Total Marks  Percentage
# 8       56.0         55          208        41.6

# %%
df.notnull()
# Out:
#     Rollno   Name  Gender  Branch  Attendence  Phy_marks  Che_marks  \
# 0     True   True    True    True        True       True       True
# 1     True   True    True    True        True       True       True
# 2     True   True    True    True        True       True       True
# 3     True   True    True    True        True       True       True
# 4     True   True    True    True        True       True      False
# 5     True   True    True    True        True       True       True
# 6     True   True    True    True        True       True       True
# 7     True   True    True    True        True       True       True
# 8     True   True    True    True        True      False      False
# 9     True   True    True    True        True       True       True
# 10    True   True    True    True        True       True       True
# 11    True  False    True    True        True       True       True
# 12    True   True    True    True        True       True       True
# ...

# %%
series = pd.notnull(df["Che_marks"])
df[series]
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp          72       62.0       98.0
# 1        2    Reyansh      M     IT          58       62.0       83.0
# 2        3      Aarav      M     IT          57      -20.0      100.0
# 3        4     Atharv      M     IT          60       89.0       83.0
# 5        6      Advik      M   ENTC          94       99.0       84.0
# 6        7       Ansh      M   ENTC          98       88.0       95.0
# 7        8     Ishaan      M   ENTC          75       66.0       51.0
# 9       10  Siddharth      M   ENTC          96       67.0       78.0
# 10      11     Vihaan      M   ENTC          82       54.0       70.0
# 11      12        NaN      M     IT          75       64.0       67.0
# 12      13     Aarush      M     IT          67       56.0       81.0
# 13      14        Leo      M     IT          98      -34.0       70.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Total Marks']=le.fit_transform(df['Total Marks'])
newdf=df
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp          72       62.0       98.0
# 1        2    Reyansh      M     IT          58       62.0       83.0
# 2        3      Aarav      M     IT          57      -20.0      100.0
# 3        4     Atharv      M     IT          60       89.0       83.0
# 4        5     Vivaan      M   Comp          85       90.0        NaN
# 5        6      Advik      M   ENTC          94       99.0       84.0
# 6        7       Ansh      M   ENTC          98       88.0       95.0
# 7        8     Ishaan      M   ENTC          75       66.0       51.0
# 8        9      Dhruv      M   ENTC          63        NaN        NaN
# 9       10  Siddharth      M   ENTC          96       67.0       78.0
# 10      11     Vihaan      M   ENTC          82       54.0       70.0
# 11      12        NaN      M     IT          75       64.0       67.0
# ...

# %%
ndf = df
ndf.fillna(0)
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp          72       62.0       98.0
# 1        2    Reyansh      M     IT          58       62.0       83.0
# 2        3      Aarav      M     IT          57      -20.0      100.0
# 3        4     Atharv      M     IT          60       89.0       83.0
# 4        5     Vivaan      M   Comp          85       90.0        0.0
# 5        6      Advik      M   ENTC          94       99.0       84.0
# 6        7       Ansh      M   ENTC          98       88.0       95.0
# 7        8     Ishaan      M   ENTC          75       66.0       51.0
# 8        9      Dhruv      M   ENTC          63        0.0        0.0
# 9       10  Siddharth      M   ENTC          96       67.0       78.0
# 10      11     Vihaan      M   ENTC          82       54.0       70.0
# 11      12          0      M     IT          75       64.0       67.0
# ...

# %% [markdown]
# # New section

# %%
data = df
data['Phy_marks']=data['Phy_marks'].fillna(data['Phy_marks'].mean())
data['Phy_marks']=data['Phy_marks'].fillna(data['Phy_marks'].median())
data['Phy_marks']=data['Phy_marks'].fillna(data['Phy_marks'].std())
data['Phy_marks']=data['Phy_marks'].fillna(data['Phy_marks'].min())
data['Phy_marks']=data['Phy_marks'].fillna(data['Phy_marks'].max())
data
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp          72  62.000000       98.0
# 1        2    Reyansh      M     IT          58  62.000000       83.0
# 2        3      Aarav      M     IT          57 -20.000000      100.0
# 3        4     Atharv      M     IT          60  89.000000       83.0
# 4        5     Vivaan      M   Comp          85  90.000000        NaN
# 5        6      Advik      M   ENTC          94  99.000000       84.0
# 6        7       Ansh      M   ENTC          98  88.000000       95.0
# 7        8     Ishaan      M   ENTC          75  66.000000       51.0
# 8        9      Dhruv      M   ENTC          63  63.421053        NaN
# 9       10  Siddharth      M   ENTC          96  67.000000       78.0
# 10      11     Vihaan      M   ENTC          82  54.000000       70.0
# 11      12        NaN      M     IT          75  64.000000       67.0
# ...

# %%
m_v=df['Che_marks'].mean()
df['Che_marks'].fillna(value=m_v,inplace=True)
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks   Che_marks  \
# 0        1   Mohammed      M   Comp          72  62.000000   98.000000
# 1        2    Reyansh      M     IT          58  62.000000   83.000000
# 2        3      Aarav      M     IT          57 -20.000000  100.000000
# 3        4     Atharv      M     IT          60  89.000000   83.000000
# 4        5     Vivaan      M   Comp          85  90.000000   80.764706
# 5        6      Advik      M   ENTC          94  99.000000   84.000000
# 6        7       Ansh      M   ENTC          98  88.000000   95.000000
# 7        8     Ishaan      M   ENTC          75  66.000000   51.000000
# 8        9      Dhruv      M   ENTC          63  63.421053   80.764706
# 9       10  Siddharth      M   ENTC          96  67.000000   78.000000
# 10      11     Vihaan      M   ENTC          82  54.000000   70.000000
# 11      12        NaN      M     IT          75  64.000000   67.000000
# ...

# %%
ndf.replace(to_replace=np.nan,value=-99)
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks   Che_marks  \
# 0        1   Mohammed      M   Comp          72  62.000000   98.000000
# 1        2    Reyansh      M     IT          58  62.000000   83.000000
# 2        3      Aarav      M     IT          57 -20.000000  100.000000
# 3        4     Atharv      M     IT          60  89.000000   83.000000
# 4        5     Vivaan      M   Comp          85  90.000000   80.764706
# 5        6      Advik      M   ENTC          94  99.000000   84.000000
# 6        7       Ansh      M   ENTC          98  88.000000   95.000000
# 7        8     Ishaan      M   ENTC          75  66.000000   51.000000
# 8        9      Dhruv      M   ENTC          63  63.421053   80.764706
# 9       10  Siddharth      M   ENTC          96  67.000000   78.000000
# 10      11     Vihaan      M   ENTC          82  54.000000   70.000000
# 11      12        -99      M     IT          75  64.000000   67.000000
# ...

# %%
ndf.dropna()
# Out:
#     Rollno      Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1  Mohammed      M   Comp          72  62.000000  98.000000
# 1        2   Reyansh      M     IT          58  62.000000  83.000000
# 3        4    Atharv      M     IT          60  89.000000  83.000000
# 4        5    Vivaan      M   Comp          85  90.000000  80.764706
# 5        6     Advik      M   ENTC          94  99.000000  84.000000
# 6        7      Ansh      M   ENTC          98  88.000000  95.000000
# 7        8    Ishaan      M   ENTC          75  66.000000  51.000000
# 8        9     Dhruv      M   ENTC          63  63.421053  80.764706
# 10      11    Vihaan      M   ENTC          82  54.000000  70.000000
# 13      14       Leo      M     IT          98 -34.000000  70.000000
# 14      15    Maryam      F     IT          64  87.000000  60.000000
# 15      16    Saanvi      F   Comp          66  90.000000  95.000000
# 16      17   Zaranew      F   Comp          93  54.000000  80.764706
# ...

# %%
ndf.dropna(how='all')
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks   Che_marks  \
# 0        1   Mohammed      M   Comp          72  62.000000   98.000000
# 1        2    Reyansh      M     IT          58  62.000000   83.000000
# 2        3      Aarav      M     IT          57 -20.000000  100.000000
# 3        4     Atharv      M     IT          60  89.000000   83.000000
# 4        5     Vivaan      M   Comp          85  90.000000   80.764706
# 5        6      Advik      M   ENTC          94  99.000000   84.000000
# 6        7       Ansh      M   ENTC          98  88.000000   95.000000
# 7        8     Ishaan      M   ENTC          75  66.000000   51.000000
# 8        9      Dhruv      M   ENTC          63  63.421053   80.764706
# 9       10  Siddharth      M   ENTC          96  67.000000   78.000000
# 10      11     Vihaan      M   ENTC          82  54.000000   70.000000
# 11      12        NaN      M     IT          75  64.000000   67.000000
# ...

# %%
ndf.dropna(axis =1)
# Out:
#     Rollno Gender Branch  Attendence  Phy_marks   Che_marks  SME_marks  \
# 0        1      M   Comp          72  62.000000   98.000000         36
# 1        2      M     IT          58  62.000000   83.000000         34
# 2        3      M     IT          57 -20.000000  100.000000         36
# 3        4      M     IT          60  89.000000   83.000000         23
# 4        5      M   Comp          85  90.000000   80.764706         56
# 5        6      M   ENTC          94  99.000000   84.000000         99
# 6        7      M   ENTC          98  88.000000   95.000000         78
# 7        8      M   ENTC          75  66.000000   51.000000         76
# 8        9      M   ENTC          63  63.421053   80.764706         55
# 9       10      M   ENTC          96  67.000000   78.000000         98
# 10      11      M   ENTC          82  54.000000   70.000000         56
# 11      12      M     IT          75  64.000000   67.000000         87
# ...

# %%
new_data=ndf.dropna(axis=0,how='any')
new_data
# Out:
#     Rollno      Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1  Mohammed      M   Comp          72  62.000000  98.000000
# 1        2   Reyansh      M     IT          58  62.000000  83.000000
# 3        4    Atharv      M     IT          60  89.000000  83.000000
# 4        5    Vivaan      M   Comp          85  90.000000  80.764706
# 5        6     Advik      M   ENTC          94  99.000000  84.000000
# 6        7      Ansh      M   ENTC          98  88.000000  95.000000
# 7        8    Ishaan      M   ENTC          75  66.000000  51.000000
# 8        9     Dhruv      M   ENTC          63  63.421053  80.764706
# 10      11    Vihaan      M   ENTC          82  54.000000  70.000000
# 13      14       Leo      M     IT          98 -34.000000  70.000000
# 14      15    Maryam      F     IT          64  87.000000  60.000000
# 15      16    Saanvi      F   Comp          66  90.000000  95.000000
# 16      17   Zaranew      F   Comp          93  54.000000  80.764706
# ...
